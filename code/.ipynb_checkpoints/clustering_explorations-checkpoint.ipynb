# %% [markdown]
# # Libraries

# %%
#libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


from sklearn.cluster import DBSCAN

from sklearn.decomposition import PCA

# %% [markdown]
# # Explore Data and Distributions of Features

# %%
#data
votecensus_2020 = pd.read_csv('../data/clean/votemargins_census_joined_2020.csv') # relative path
votecensus_2020.head()
# Out:
#     unique_id  year state_po county_name  votemargin_DR  \
# 0  2020_01001  2020       AL     AUTAUGA          -44.4
# 1  2020_01003  2020       AL     BALDWIN          -53.8
# 2  2020_01005  2020       AL     BARBOUR           -7.7
# 3  2020_01007  2020       AL        BIBB          -57.7
# 4  2020_01009  2020       AL      BLOUNT          -80.0
#
#    proportion_explained_by_DR  totalvotes  DP2_education_bachelormin_PE  \
# 0                        98.5       27770                          28.3
# 1                        98.6      109679                          31.9
# 2                        99.2       10518                          11.6
# 3                        99.1        9595                          11.3
# 4                        99.1       27588                          13.3
#
#    DP2_marital_male_nevermarried_PE  DP2_foreign_born_PE  \
# 0                              28.9                  2.3
# 1                              27.1                  3.4
# 2                              41.8                  2.6
# 3                              39.8                  1.6
# 4                              27.1                  4.4
#
#    DP3_employment_unemp_PE  DP3_median_income_norm
# 0                      1.7                    28.6
# 1                      2.3                    31.6
# 2                      3.2                    10.2
# 3                      3.6                    23.6
# 4                      2.7                    21.3

# %%
votecensus_2020.drop('totalvotes', axis=1, inplace=True)
votecensus_2020_clustered = votecensus_2020.copy()

# %%
# state our columns
columns = ['votemargin_DR', 
           'proportion_explained_by_DR', 
           'DP2_education_bachelormin_PE', 
           'DP2_marital_male_nevermarried_PE', 
           'DP2_foreign_born_PE',
          'DP3_employment_unemp_PE',
          'DP3_median_income_norm']

# set up the matplotlib histogram
plt.figure(figsize=(12, 8))

#looping over our variable (columns) to create histograms
for i, column in enumerate(columns, 1):
    plt.subplot(4, 2, i)  # create a 4x2 grid for 7 plots
    plt.hist(votecensus_2020[column], 
             bins=20, 
             color='blue', 
             edgecolor='black', 
             alpha=0.7)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

# layout and print
plt.tight_layout()
plt.show()

# %%
# given that our features are not on the same scale (votemargin, specifically)
# we are going to standardize!

# but given the skew we see in FOREIGN BORN and  PROPORTION EXPLAINED BY DR
# we may have to further transform our data

# %%
features = votecensus_2020.drop(columns=['unique_id', 'year', 'state_po', 'county_name'])  # Drop ID column for preprocessing

# %% [markdown]
# # YEO-Johnson Transformation (Alternative to Standardization)

# %%
#Yeo-Johnson Transformation (handles zero and negative values):
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson')
features_yeo = pt.fit_transform(features)
features_yeo_df = pd.DataFrame(features_yeo, columns=features.columns)

# %%
# state our columns
columns = ['votemargin_DR', 
           'proportion_explained_by_DR', 
           'DP2_education_bachelormin_PE', 
           'DP2_marital_male_nevermarried_PE', 
           'DP2_foreign_born_PE',
          'DP3_employment_unemp_PE',
          'DP3_median_income_norm']

# set up the matplotlib histogram
plt.figure(figsize=(12, 8))

#looping over our variable (columns) to create histograms
for i, column in enumerate(columns, 1):
    plt.subplot(4, 2, i)  # create a 4x2 grid for 7 plots
    plt.hist(features_yeo_df[column], 
             bins=20, 
             color='blue', 
             edgecolor='black', 
             alpha=0.7)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

# layout and print
plt.tight_layout()
plt.show()

# %% [markdown]
# # KMEANS

# %%
# inertia is our added SSEs, so lets find it for each k
# forloop over range 2-20
inertia = [KMeans(n_clusters=i).fit(features_yeo_df).inertia_ for i in range(2,25)]

# plot into elbow plot
plt.plot(range(2,25), inertia)
plt.xlabel('Number of Clusters')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('SSE Progression with K Clusters')
plt.show()

# %%
# Iterate through different values of k
for k in range(2, 25):
    # Fit the KMeans model
    model = KMeans(n_clusters=k, random_state=42)
    labels = model.fit_predict(features_scaled_df)
    
    # Compute silhouette score
    score = silhouette_score(features_yeo_df, labels)
    
    # Count the number of observations in each cluster
    unique_labels, counts = np.unique(labels, return_counts=True)
    
    # Print results
    print(f"K = {k}")
    print(f"Silhouette Score: {score:.4f}")
    print("Cluster Distribution:")
    for label, count in zip(unique_labels, counts):
        print(f"  Cluster {label}: {count} observations")
    print("-" * 50)
# Out:
# K = 2
# Silhouette Score: 0.2577
# Cluster Distribution:
#   Cluster 0: 754 observations
#   Cluster 1: 2359 observations
# --------------------------------------------------
# K = 3
# Silhouette Score: 0.2169
# Cluster Distribution:
#   Cluster 0: 575 observations
#   Cluster 1: 610 observations
#   Cluster 2: 1928 observations
# --------------------------------------------------
# K = 4
# Silhouette Score: 0.1556
# Cluster Distribution:
#   Cluster 0: 826 observations
#   Cluster 1: 489 observations
#   Cluster 2: 1498 observations
#   Cluster 3: 300 observations
# --------------------------------------------------
# K = 5
# Silhouette Score: 0.1395
# Cluster Distribution:
#   Cluster 0: 624 observations
#   Cluster 1: 338 observations
#   Cluster 2: 1007 observations
#   Cluster 3: 237 observations
#   Cluster 4: 907 observations
# --------------------------------------------------
# K = 6
# Silhouette Score: 0.1284
# Cluster Distribution:
#   Cluster 0: 274 observations
#   Cluster 1: 327 observations
#   Cluster 2: 951 observations
#   Cluster 3: 215 observations
#   Cluster 4: 499 observations
#   Cluster 5: 847 observations
# --------------------------------------------------
# K = 7
# Silhouette Score: 0.1273
# Cluster Distribution:
#   Cluster 0: 262 observations
#   Cluster 1: 117 observations
#   Cluster 2: 904 observations
#   Cluster 3: 208 observations
#   Cluster 4: 515 observations
#   Cluster 5: 826 observations
#   Cluster 6: 281 observations
# --------------------------------------------------
# K = 8
# Silhouette Score: 0.1146
# Cluster Distribution:
#   Cluster 0: 247 observations
#   Cluster 1: 662 observations
#   Cluster 2: 287 observations
#   Cluster 3: 803 observations
#   Cluster 4: 650 observations
#   Cluster 5: 285 observations
#   Cluster 6: 64 observations
#   Cluster 7: 115 observations
# --------------------------------------------------
# K = 9
# Silhouette Score: 0.1230
# Cluster Distribution:
#   Cluster 0: 226 observations
#   Cluster 1: 665 observations
#   Cluster 2: 237 observations
#   Cluster 3: 798 observations
#   Cluster 4: 641 observations
#   Cluster 5: 172 observations
#   Cluster 6: 73 observations
#   Cluster 7: 112 observations
#   Cluster 8: 189 observations
# --------------------------------------------------
# K = 10
# Silhouette Score: 0.1213
# Cluster Distribution:
#   Cluster 0: 226 observations
#   Cluster 1: 667 observations
#   Cluster 2: 191 observations
#   Cluster 3: 648 observations
#   Cluster 4: 310 observations
#   Cluster 5: 105 observations
#   Cluster 6: 104 observations
#   Cluster 7: 67 observations
#   Cluster 8: 192 observations
#   Cluster 9: 603 observations
# --------------------------------------------------
# K = 11
# Silhouette Score: 0.1107
# Cluster Distribution:
#   Cluster 0: 209 observations
#   Cluster 1: 384 observations
#   Cluster 2: 182 observations
#   Cluster 3: 742 observations
#   Cluster 4: 552 observations
#   Cluster 5: 181 observations
#   Cluster 6: 68 observations
#   Cluster 7: 73 observations
#   Cluster 8: 185 observations
#   Cluster 9: 435 observations
#   Cluster 10: 102 observations
# --------------------------------------------------
# K = 12
# Silhouette Score: 0.1027
# Cluster Distribution:
#   Cluster 0: 176 observations
#   Cluster 1: 385 observations
#   Cluster 2: 164 observations
#   Cluster 3: 553 observations
#   Cluster 4: 517 observations
#   Cluster 5: 159 observations
#   Cluster 6: 66 observations
#   Cluster 7: 64 observations
#   Cluster 8: 161 observations
#   Cluster 9: 356 observations
#   Cluster 10: 106 observations
#   Cluster 11: 406 observations
# --------------------------------------------------
# K = 13
# Silhouette Score: 0.1055
# Cluster Distribution:
#   Cluster 0: 172 observations
#   Cluster 1: 122 observations
#   Cluster 2: 137 observations
#   Cluster 3: 500 observations
#   Cluster 4: 444 observations
#   Cluster 5: 155 observations
#   Cluster 6: 57 observations
#   Cluster 7: 64 observations
#   Cluster 8: 170 observations
#   Cluster 9: 370 observations
#   Cluster 10: 68 observations
#   Cluster 11: 408 observations
#   Cluster 12: 446 observations
# --------------------------------------------------
# K = 14
# Silhouette Score: 0.1012
# Cluster Distribution:
#   Cluster 0: 106 observations
#   Cluster 1: 103 observations
#   Cluster 2: 177 observations
#   Cluster 3: 521 observations
#   Cluster 4: 346 observations
#   Cluster 5: 151 observations
#   Cluster 6: 50 observations
#   Cluster 7: 19 observations
#   Cluster 8: 150 observations
#   Cluster 9: 331 observations
#   Cluster 10: 70 observations
#   Cluster 11: 328 observations
#   Cluster 12: 407 observations
#   Cluster 13: 354 observations
# --------------------------------------------------
# K = 15
# Silhouette Score: 0.1009
# Cluster Distribution:
#   Cluster 0: 98 observations
#   Cluster 1: 100 observations
#   Cluster 2: 165 observations
#   Cluster 3: 500 observations
#   Cluster 4: 289 observations
#   Cluster 5: 161 observations
#   Cluster 6: 45 observations
#   Cluster 7: 19 observations
#   Cluster 8: 120 observations
#   Cluster 9: 271 observations
#   Cluster 10: 67 observations
#   Cluster 11: 333 observations
#   Cluster 12: 343 observations
#   Cluster 13: 281 observations
#   Cluster 14: 321 observations
# --------------------------------------------------
# K = 16
# Silhouette Score: 0.0964
# Cluster Distribution:
#   Cluster 0: 81 observations
#   Cluster 1: 103 observations
#   Cluster 2: 151 observations
#   Cluster 3: 372 observations
#   Cluster 4: 466 observations
#   Cluster 5: 123 observations
#   Cluster 6: 37 observations
#   Cluster 7: 18 observations
#   Cluster 8: 129 observations
#   Cluster 9: 236 observations
#   Cluster 10: 71 observations
#   Cluster 11: 232 observations
#   Cluster 12: 265 observations
#   Cluster 13: 279 observations
#   Cluster 14: 295 observations
#   Cluster 15: 255 observations
# --------------------------------------------------
# K = 17
# Silhouette Score: 0.0956
# Cluster Distribution:
#   Cluster 0: 123 observations
#   Cluster 1: 102 observations
#   Cluster 2: 149 observations
#   Cluster 3: 361 observations
#   Cluster 4: 448 observations
#   Cluster 5: 125 observations
#   Cluster 6: 37 observations
#   Cluster 7: 18 observations
#   Cluster 8: 120 observations
#   Cluster 9: 234 observations
#   Cluster 10: 71 observations
#   Cluster 11: 241 observations
#   Cluster 12: 252 observations
#   Cluster 13: 278 observations
#   Cluster 14: 287 observations
#   Cluster 15: 264 observations
#   Cluster 16: 3 observations
# --------------------------------------------------
# K = 18
# Silhouette Score: 0.0931
# Cluster Distribution:
#   Cluster 0: 98 observations
#   Cluster 1: 205 observations
#   Cluster 2: 161 observations
#   Cluster 3: 430 observations
#   Cluster 4: 336 observations
#   Cluster 5: 106 observations
#   Cluster 6: 35 observations
#   Cluster 7: 18 observations
#   Cluster 8: 121 observations
#   Cluster 9: 350 observations
#   Cluster 10: 57 observations
#   Cluster 11: 211 observations
#   Cluster 12: 251 observations
#   Cluster 13: 249 observations
#   Cluster 14: 181 observations
#   Cluster 15: 211 observations
#   Cluster 16: 3 observations
#   Cluster 17: 90 observations
# --------------------------------------------------
# K = 19
# Silhouette Score: 0.0942
# Cluster Distribution:
#   Cluster 0: 78 observations
#   Cluster 1: 144 observations
#   Cluster 2: 167 observations
#   Cluster 3: 427 observations
#   Cluster 4: 382 observations
#   Cluster 5: 123 observations
#   Cluster 6: 32 observations
#   Cluster 7: 19 observations
#   Cluster 8: 94 observations
#   Cluster 9: 314 observations
#   Cluster 10: 56 observations
#   Cluster 11: 219 observations
#   Cluster 12: 173 observations
#   Cluster 13: 223 observations
#   Cluster 14: 198 observations
#   Cluster 15: 187 observations
#   Cluster 16: 3 observations
#   Cluster 17: 68 observations
#   Cluster 18: 206 observations
# --------------------------------------------------
# K = 20
# Silhouette Score: 0.0860
# Cluster Distribution:
#   Cluster 0: 79 observations
#   Cluster 1: 146 observations
#   Cluster 2: 126 observations
#   Cluster 3: 400 observations
#   Cluster 4: 313 observations
#   Cluster 5: 101 observations
#   Cluster 6: 30 observations
#   Cluster 7: 110 observations
#   Cluster 8: 115 observations
#   Cluster 9: 286 observations
#   Cluster 10: 55 observations
#   Cluster 11: 203 observations
#   Cluster 12: 165 observations
#   Cluster 13: 310 observations
#   Cluster 14: 175 observations
#   Cluster 15: 224 observations
#   Cluster 16: 3 observations
#   Cluster 17: 69 observations
#   Cluster 18: 198 observations
#   Cluster 19: 5 observations
# --------------------------------------------------
# K = 21
# Silhouette Score: 0.0838
# Cluster Distribution:
#   Cluster 0: 56 observations
#   Cluster 1: 187 observations
#   Cluster 2: 117 observations
#   Cluster 3: 364 observations
#   Cluster 4: 116 observations
#   Cluster 5: 123 observations
#   Cluster 6: 186 observations
#   Cluster 7: 87 observations
#   Cluster 8: 66 observations
#   Cluster 9: 79 observations
#   Cluster 10: 86 observations
#   Cluster 11: 276 observations
#   Cluster 12: 298 observations
#   Cluster 13: 281 observations
#   Cluster 14: 40 observations
#   Cluster 15: 136 observations
#   Cluster 16: 149 observations
#   Cluster 17: 206 observations
#   Cluster 18: 5 observations
#   Cluster 19: 199 observations
#   Cluster 20: 56 observations
# --------------------------------------------------
# K = 22
# Silhouette Score: 0.0876
# Cluster Distribution:
#   Cluster 0: 55 observations
#   Cluster 1: 134 observations
#   Cluster 2: 131 observations
#   Cluster 3: 337 observations
#   Cluster 4: 72 observations
#   Cluster 5: 153 observations
#   Cluster 6: 180 observations
#   Cluster 7: 65 observations
#   Cluster 8: 63 observations
#   Cluster 9: 101 observations
#   Cluster 10: 85 observations
#   Cluster 11: 278 observations
#   Cluster 12: 297 observations
#   Cluster 13: 231 observations
#   Cluster 14: 32 observations
#   Cluster 15: 153 observations
#   Cluster 16: 146 observations
#   Cluster 17: 222 observations
#   Cluster 18: 5 observations
#   Cluster 19: 172 observations
#   Cluster 20: 44 observations
#   Cluster 21: 157 observations
# --------------------------------------------------
# K = 23
# Silhouette Score: 0.0859
# Cluster Distribution:
#   Cluster 0: 56 observations
#   Cluster 1: 116 observations
#   Cluster 2: 137 observations
#   Cluster 3: 300 observations
#   Cluster 4: 78 observations
#   Cluster 5: 108 observations
#   Cluster 6: 154 observations
#   Cluster 7: 58 observations
#   Cluster 8: 61 observations
#   Cluster 9: 59 observations
#   Cluster 10: 81 observations
#   Cluster 11: 241 observations
#   Cluster 12: 313 observations
#   Cluster 13: 232 observations
#   Cluster 14: 31 observations
#   Cluster 15: 134 observations
#   Cluster 16: 140 observations
#   Cluster 17: 210 observations
#   Cluster 18: 5 observations
#   Cluster 19: 193 observations
#   Cluster 20: 45 observations
#   Cluster 21: 180 observations
#   Cluster 22: 181 observations
# --------------------------------------------------
# K = 24
# Silhouette Score: 0.0876
# Cluster Distribution:
#   Cluster 0: 51 observations
#   Cluster 1: 96 observations
#   Cluster 2: 104 observations
#   Cluster 3: 317 observations
#   Cluster 4: 148 observations
#   Cluster 5: 105 observations
#   Cluster 6: 158 observations
#   Cluster 7: 59 observations
#   Cluster 8: 76 observations
#   Cluster 9: 60 observations
#   Cluster 10: 89 observations
#   Cluster 11: 202 observations
#   Cluster 12: 320 observations
#   Cluster 13: 235 observations
#   Cluster 14: 31 observations
#   Cluster 15: 140 observations
#   Cluster 16: 142 observations
#   Cluster 17: 173 observations
#   Cluster 18: 4 observations
#   Cluster 19: 172 observations
#   Cluster 20: 28 observations
#   Cluster 21: 168 observations
#   Cluster 22: 182 observations
#   Cluster 23: 53 observations
# --------------------------------------------------

# %%
# seems like 10 is a good place to stop, even though silhouette drops pretty badly from k = 3, 4
k = 10
model = KMeans(n_clusters=k, random_state=42)
kmeans_labels = model.fit_predict(features_scaled_df)

# %%
# Apply PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
features_pca = pca.fit_transform(features_yeo_df)

# Visualize the clusters in 2D
plt.figure(figsize=(10, 7))
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=kmeans_labels, cmap='viridis', s=30)
plt.colorbar(label='Cluster')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Visualization of KMeans Clusters')
plt.show()

# %% [markdown]
# # DBSCAN

# %%
for eps_val in [0.5, 0.6, 0.7, 0.8, 0.9, 1, 1.1, 1.2, 1.3, 1.4, 1.5]:  # Test multiple values
    dbscan = DBSCAN(eps=eps_val, min_samples=5)
    dbscan_labels = dbscan.fit_predict(features_yeo_df)
    print(f"eps={eps_val}, Number of Clusters: {len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)}, Noise Points: {np.sum(dbscan_labels == -1)}")
# Out:
# eps=0.5, Number of Clusters: 2, Noise Points: 3100
# eps=0.6, Number of Clusters: 23, Noise Points: 2840
# eps=0.7, Number of Clusters: 21, Noise Points: 2268
# eps=0.8, Number of Clusters: 13, Noise Points: 1591
# eps=0.9, Number of Clusters: 5, Noise Points: 1090
# eps=1, Number of Clusters: 3, Noise Points: 721
# eps=1.1, Number of Clusters: 4, Noise Points: 486
# eps=1.2, Number of Clusters: 1, Noise Points: 336
# eps=1.3, Number of Clusters: 1, Noise Points: 246
# eps=1.4, Number of Clusters: 1, Noise Points: 179
# eps=1.5, Number of Clusters: 1, Noise Points: 131

# %%
# seems like 0.9 is a good eps to set
dbscan = DBSCAN(eps=0.9, min_samples=5)  # Adjust min_samples if needed
dbscan_labels = dbscan.fit_predict(features_yeo_df)

# Check the cluster labels
print("Cluster Labels:", set(dbscan_labels))
noise_percentage = np.sum(dbscan_labels == -1) / len(dbscan_labels) * 100
print(f"Noise Percentage: {noise_percentage:.2f}%")
# Out:
# Cluster Labels: {0, 1, 2, 3, 4, -1}
# Noise Percentage: 35.01%

# %%
# Reduce data to 2D
pca = PCA(n_components=2)
features_pca = pca.fit_transform(features_yeo_df)

# Plot clusters
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=dbscan_labels, cmap='viridis', s=10)
plt.title(f"DBSCAN Clusters (eps={eps_val})")
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# # Explore Results

# %%
votecensus_2020_clustered['kmeans_labels'] = kmeans_labels
votecensus_2020_clustered['dbscan_labels'] = dbscan_labels
votecensus_2020_clustered.head()
# Out:
#     unique_id  year state_po county_name  votemargin_DR  \
# 0  2020_01001  2020       AL     AUTAUGA          -44.4
# 1  2020_01003  2020       AL     BALDWIN          -53.8
# 2  2020_01005  2020       AL     BARBOUR           -7.7
# 3  2020_01007  2020       AL        BIBB          -57.7
# 4  2020_01009  2020       AL      BLOUNT          -80.0
#
#    proportion_explained_by_DR  DP2_education_bachelormin_PE  \
# 0                        98.5                          28.3
# 1                        98.6                          31.9
# 2                        99.2                          11.6
# 3                        99.1                          11.3
# 4                        99.1                          13.3
#
#    DP2_marital_male_nevermarried_PE  DP2_foreign_born_PE  \
# 0                              28.9                  2.3
# 1                              27.1                  3.4
# 2                              41.8                  2.6
# 3                              39.8                  1.6
# 4                              27.1                  4.4
#
#    DP3_employment_unemp_PE  DP3_median_income_norm  kmeans_cluster  \
# 0                      1.7                    28.6               1
# 1                      2.3                    31.6               1
# 2                      3.2                    10.2               2
# 3                      3.6                    23.6               3
# 4                      2.7                    21.3               3
#
#    dbscan_labels  kmeans_labels
# 0              0              1
# 1              0              1
# 2              2              2
# 3             -1              3
# 4              0              3

# %%
votecensus_2020_clustered_slice = votecensus_2020_clustered[votecensus_2020_clustered.dbscan_labels > 0]

# %%
votecensus_2020_clustered_slice.head(20).sort_values(['dbscan_labels', 'kmeans_labels'])
# Out:
#        unique_id  year state_po county_name  votemargin_DR  \
# 217   2020_06115  2020       CA        YUBA          -21.6
# 2210  2020_41059  2020       OR    UMATILLA          -32.0
# 2934  2020_53021  2020       WA    FRANKLIN          -14.5
# 2936  2020_53025  2020       WA       GRANT          -34.4
# 2962  2020_53077  2020       WA      YAKIMA           -7.7
# 2     2020_01005  2020       AL     BARBOUR           -7.7
# 441   2020_13163  2020       GA   JEFFERSON            6.9
# 495   2020_13273  2020       GA     TERRELL            8.4
# 1866  2020_37007  2020       NC       ANSON            4.2
# 2313  2020_45049  2020       SC     HAMPTON           15.2
# 518   2020_13319  2020       GA   WILKINSON          -12.3
# 640   2020_17145  2020       IL       PERRY          -46.8
# 2485  2020_47169  2020       TN   TROUSDALE          -48.1
# 2689  2020_48391  2020       TX     REFUGIO          -32.7
# 1100  2020_22029  2020       LA   CONCORDIA          -26.9
# 1413  2020_28079  2020       MS       LEAKE          -14.5
# 1420  2020_28093  2020       MS    MARSHALL            3.1
# 1427  2020_28107  2020       MS      PANOLA           -4.2
# 2294  2020_45011  2020       SC    BARNWELL           -7.5
# 2303  2020_45029  2020       SC    COLLETON           -9.5
#
#       proportion_explained_by_DR  DP2_education_bachelormin_PE  \
# 217                         97.0                          18.0
# 2210                        96.8                          17.5
# 2934                        96.8                          18.9
# 2936                        97.1                          18.0
# 2962                        97.4                          17.6
# 2                           99.2                          11.6
# 441                         99.4                          10.7
# 495                         99.2                          10.2
# 1866                        99.2                          11.1
# 2313                        99.2                          11.3
# 518                         99.4                          11.2
# 640                         98.7                          11.6
# 2485                        98.7                          11.6
# 2689                        98.6                          11.1
# 1100                        98.9                          13.3
# 1413                        99.2                          15.9
# 1420                        98.8                          13.9
# 1427                        99.0                          16.3
# 2294                        98.9                          14.7
# 2303                        98.8                          16.3
#
#       DP2_marital_male_nevermarried_PE  DP2_foreign_born_PE  \
# 217                               36.9                 12.1
# 2210                              36.9                  9.6
# 2934                              37.4                 21.6
# 2936                              35.5                 17.5
# 2962                              36.4                 18.4
# 2                                 41.8                  2.6
# 441                               37.9                  2.3
# 495                               39.0                  3.3
# 1866                              41.9                  2.8
# 2313                              37.8                  3.2
# 518                               33.5                  2.3
# 640                               39.1                  1.3
# 2485                              40.4                  0.9
# 2689                              36.6                  1.2
# 1100                              42.4                  1.7
# 1413                              40.5                  1.7
# 1420                              39.0                  1.6
# 1427                              40.3                  1.3
# 2294                              40.8                  2.1
# 2303                              35.6                  2.7
#
#       DP3_employment_unemp_PE  DP3_median_income_norm  kmeans_cluster  \
# 217                       3.9                    29.7               0
# 2210                      4.0                    28.6               0
# 2934                      3.7                    35.7               6
# 2936                      3.6                    29.5               6
# 2962                      4.0                    26.1               6
# 2                         3.2                    10.2               2
# 441                       3.5                    11.8               2
# 495                       4.0                    10.4               2
# 1866                      4.1                    14.0               2
# 2313                      4.2                    12.7               2
# 518                       3.7                    11.7               3
# 640                       2.7                    23.5               9
# 2485                      2.5                    27.8               9
# 2689                      3.5                    23.0               9
# 1100                      4.0                    11.2               2
# 1413                      4.3                    11.5               2
# 1420                      3.4                    16.9               2
# 1427                      4.0                    12.0               2
# 2294                      3.6                    12.2               2
# 2303                      3.9                    11.6               2
#
#       dbscan_labels  kmeans_labels
# 217               1              0
# 2210              1              0
# 2934              1              6
# 2936              1              6
# 2962              1              6
# 2                 2              2
# 441               2              2
# 495               2              2
# 1866              2              2
# 2313              2              2
# 518               2              3
# 640               3              9
# 2485              3              9
# 2689              3              9
# 1100              4              2
# 1413              4              2
# 1420              4              2
# 1427              4              2
# 2294              4              2
# 2303              4              2

# %%
votecensus_2020_clustered_slice.to_csv('../data/results/votecensus_2020_clustered_slice.csv', index=False)
